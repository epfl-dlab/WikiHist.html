# %%
import numpy as np
import json

# %%
sizes = []
files = []

with open("wiki.txt") as file:
    for line in file:
        parts = line.split()
        if len(parts) > 5:
            sizes.append(float(parts[4]))
            files.append((parts[8], float(parts[4])))

# %%
# Prints the items which are put in a  
# knapsack of capacity W 
def printknapSack(W, wt, n): 
    K = [[0 for w in range(W + 1)] 
            for i in range(n + 1)] 

    # Build table K[][] in bottom 
    # up manner 
    for i in range(n + 1): 
        for w in range(W + 1): 
            if i == 0 or w == 0: 
                K[i][w] = 0
            elif wt[i - 1] <= w: 
                K[i][w] = max(wt[i - 1]  
                  + K[i - 1][w - wt[i - 1]], 
                               K[i - 1][w])
            else: 
                K[i][w] = K[i - 1][w] 
  
    # stores the result of Knapsack 
    result = K[n][W]
    res = K[n][W] 
    # print(res)
    
    values = []
      
    w = W 
    for i in range(n, 0, -1): 
        if res <= 0: 
            break
        # either the result comes from the 
        # top (K[i-1][w]) or from (val[i-1] 
        # + K[i-1] [w-wt[i-1]]) as in Knapsack 
        # table. If it comes from the latter 
        # one/ it means the item is included. 
        if res == K[i - 1][w]: 
            continue
        else: 
  
            # This item is included.
            # print(wt[i - 1])
            values.append(wt[i - 1])
              
            # Since this weight is included 
            # its value is deducted 
            res = res - wt[i - 1] 
            w = w - wt[i - 1]
            
    return (result, values)

wt = [ 10, 20, 30 ] 
W = 50
n = len(wt) 
      
printknapSack(W, wt, n) 
  
# This code is contributed by Aryan Garg.
# Out:
# (50, [30, 20])

# %%
rez = {}
wt = [int(x) for x in sizes]

for i in range(11):
    rez[i] = printknapSack(W=1550, wt=wt, n=len(wt))
    for el in rez[i][1]:
        wt.remove(el)

# %%
total = 0
total_number = 0

for k in rez.keys():
    total += np.sum(rez[k][1])
    total_number += len(rez[k][1])
    print(len(rez[k][1]))
# Out:
# 30
# 43
# 63
# 63
# 37
# 61
# 59
# 55
# 41
# 47
# 48

# %%
total_number
# Out:
# 547

# %%
total
# Out:
# 16760

# %%
separated_files = []
tmp_files = files.copy()

for i in range(11):
    siz = sorted(rez[i][1])
    separated_files.append([])
    for s in siz:
        for f in tmp_files:
            if s == int(f[1]):
                separated_files[i].append(f)
                tmp_files.remove(f)
                break

# %%
total = 0
total_number = 0
all_files = []

for i in range(11):
    total_number += len(separated_files[i])
    for f in separated_files[i]:
        total += f[1]
        all_files.append(f[0])

# %%
total
# Out:
# 17006.399999999998

# %%
np.sum(sizes)
# Out:
# 17006.4

# %%
total_number
# Out:
# 547

# %%
len(sizes)
# Out:
# 547

# %%
np.unique(all_files).size
# Out:
# 547

# %%
sep_sizes = {}
separated_only_files = []
all_files = []
siz = 0

for i in range(11):
    separated_only_files.append([])
    sep_sizes[i] = 0
    for f in separated_files[i]:
        separated_only_files[i].append(f[0])
        all_files.append(f[0])
        sep_sizes[i] += f[1]
    siz += len(separated_only_files[i])

# %%
np.unique(all_files).shape
# Out:
# (547,)

# %%
with open('separated_files.txt', 'w') as f:
    f.write(json.dumps(separated_only_files))

# %%
separated_only_files
# Out:
# [['/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history1.xml-p30132p30303',
#   '/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2430920p2461498',
#   '/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2814172p2858587',
#   '/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2670685p2717436',
#   '/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2461499p2501546',
#   '/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2368392p2401909',
#   '/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2632005p2670684',
#   '/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2717437p2768997',
#   '/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2336425p2368391',
# ...

# %%
all_files
# Out:
# ['/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history1.xml-p30132p30303',
#  '/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2430920p2461498',
#  '/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2814172p2858587',
#  '/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2670685p2717436',
#  '/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2461499p2501546',
#  '/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2368392p2401909',
#  '/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2632005p2670684',
#  '/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2717437p2768997',
#  '/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2336425p2368391',
# ...

# %%
separated_files
# Out:
# [[('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history1.xml-p30132p30303',
#    5.1),
#   ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2430920p2461498',
#    19.8),
#   ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2814172p2858587',
#    21.7),
#   ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2670685p2717436',
#    22.4),
#   ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2461499p2501546',
#    23.5),
#   ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2368392p2401909',
#    24.5),
#   ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2632005p2670684',
#    24.3),
#   ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2717437p2768997',
#    24.8),
# ...

# %% [markdown]
# ### This is for the batch 1

# %%
separated_files = [[('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history1.xml-p30132p30303',
   5.1),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2430920p2461498',
   19.8),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2814172p2858587',
   21.7),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2670685p2717436',
   22.4),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2461499p2501546',
   23.5),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2368392p2401909',
   24.5),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2632005p2670684',
   24.3),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2717437p2768997',
   24.8),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2336425p2368391',
   25.4),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2401910p2430919',
   25.2),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2768998p2814171',
   25.6),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2593545p2632004',
   32.1),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2501547p2535815',
   34.6),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history1.xml-p21270p23011',
   66.2),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history1.xml-p5666p7556',
   66.6),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history1.xml-p7557p9295',
   66.8),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history1.xml-p2078p4105',
   67.6),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history1.xml-p28274p30131',
   67.3),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history1.xml-p11149p12919',
   69.0),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history1.xml-p17928p19583',
   69.5),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history1.xml-p9296p11148',
   69.9),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history1.xml-p19584p21269',
   70.7),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history1.xml-p16094p17927',
   71.3),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history1.xml-p10p2077',
   72.2),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history1.xml-p24871p26583',
   72.2),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history1.xml-p26584p28273',
   75.6),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history1.xml-p12920p14576',
   77.5),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history1.xml-p4106p5665',
   77.0),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history1.xml-p14577p16093',
   78.0),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2535816p2556737',
   116.4)],
 [('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history12.xml-p4903333p4971465',
   20.9),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2900117p2944386',
   21.9),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2944387p2989667',
   21.6),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history12.xml-p4221894p4280613',
   21.5),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history12.xml-p4521157p4582262',
   21.7),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history11.xml-p3653071p3706895',
   22.3),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history12.xml-p4107938p4166569',
   22.8),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history12.xml-p4342996p4404236',
   22.1),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2989668p3034148',
   23.6),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history11.xml-p3138587p3186111',
   23.3),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history11.xml-p3186112p3232992',
   23.1),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history11.xml-p3559795p3608668',
   23.7),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history12.xml-p3926863p3988729',
   23.9),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history12.xml-p3988730p4048918',
   23.5),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history12.xml-p4404237p4459742',
   23.8),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history12.xml-p4635365p4699118',
   23.9),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history11.xml-p3514985p3559794',
   24.9),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history11.xml-p3856249p3918693',
   24.1),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history12.xml-p4280614p4342995',
   24.1),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history12.xml-p4459743p4521156',
   24.4),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history12.xml-p4761994p4833081',
   24.9),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history11.xml-p3046514p3092643',
   25.2),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history11.xml-p3092644p3138586',
   25.4),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history11.xml-p3271300p3319619',
   25.4),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history11.xml-p3798954p3856248',
   25.6),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history12.xml-p4048919p4107937',
   25.2),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history12.xml-p4582263p4635364',
   26.8),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2858588p2900116',
   27.9),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history11.xml-p3319620p3372216',
   27.4),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history11.xml-p3608669p3653070',
   27.4),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history11.xml-p3746039p3798953',
   27.0),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history12.xml-p4699119p4761993',
   28.3),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history12.xml-p4971466p5033690',
   28.4),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history11.xml-p3372217p3424552',
   30.8),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history12.xml-p4166570p4221893',
   34.2),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history11.xml-p3424553p3473598',
   36.5),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2556738p2593544',
   38.9),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history11.xml-p3473599p3514984',
   40.7),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history13.xml-p5040438p5096064',
   48.0),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history11.xml-p3232993p3271299',
   49.1),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history11.xml-p3706896p3746038',
   58.9),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history13.xml-p5137570p5189362',
   78.1),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history13.xml-p5096065p5137569',
   350.9)],
 [('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history11.xml-p3918694p3926861',
   3.5),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history15.xml-p9499947p9518048',
   4.1),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p3034149p3046511',
   6.2),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history14.xml-p6605423p6696632',
   19.5),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history15.xml-p8979039p9062485',
   19.9),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history14.xml-
5),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history8.xml-p1783588p1791079',
   7.3),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history9.xml-p1941155p1952564',
   9.6),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history9.xml-p2184878p2209917',
   20.9),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history8.xml-p1751968p1783587',
   22.3),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history9.xml-p2304773p2336422',
   22.0),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history8.xml-p1353138p1384250',
   24.2),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history8.xml-p1583725p1609885',
   24.8),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history9.xml-p1983264p2016095',
   24.8),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history9.xml-p2016096p2052214',
   24.7),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history9.xml-p2272604p2304772',
   24.9),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history8.xml-p1384251p1414830',
   25.0),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history8.xml-p1720586p1751967',
   25.5),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history9.xml-p1791080p1821011',
   25.7),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history9.xml-p1821012p1850773',
   25.1),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history9.xml-p1850774p1880522',
   25.1),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history9.xml-p1953549p1983263',
   25.6),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history9.xml-p2240460p2272603',
   25.0),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history8.xml-p1326357p1353137',
   26.8),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history8.xml-p1414831p1441573',
   26.1),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history8.xml-p1494250p1525460',
   26.1),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history8.xml-p1691936p1720585',
   26.0),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history9.xml-p1880523p1910639',
   26.7),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history9.xml-p1910640p1941154',
   26.8),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history9.xml-p2052215p2083736',
   26.8),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history9.xml-p2083737p2118665',
   26.0),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history8.xml-p1441574p1468961',
   27.8),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history8.xml-p1663200p1691935',
   27.3),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history9.xml-p2118666p2155219',
   27.2),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history9.xml-p2155220p2184877',
   27.0),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history7.xml-p928638p948676',
   28.3),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history8.xml-p1268692p1296865',
   28.8),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history8.xml-p1296866p1326356',
   28.5),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history8.xml-p1558205p1583724',
   28.6),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history8.xml-p1609886p1637043',
   28.4),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history7.xml-p909164p928637',
   29.0),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history8.xml-p1525461p1558204',
   29.2),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history7.xml-p948677p968415',
   30.1),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history9.xml-p2209918p2240459',
   30.2),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history6.xml-p735437p753771',
   33.9),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history7.xml-p892914p909163',
   33.1),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history8.xml-p1637044p1663199',
   35.9),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history8.xml-p1468962p1494249',
   53.0),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history7.xml-p984234p1001250',
   56.1),
  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history7.xml-p968416p984233',
   83.6)]]

# %%
server_29 = separated_files[2]
server_28 = separated_files[3]

separated_files[2] = separated_files[9]
separated_files[3] = separated_files[10]

separated_files[9] = server_28
separated_files[10] = server_29

# %%
total = 0
total_number = 0
batch_one = {}
batch_one_size = {}
other_files = []

for i in range(11):
    if i == 9 or i == 10:
        sep_fil = separated_files[i][:30]
        other_files = other_files + separated_files[i][30:]
    else:
        sep_fil = separated_files[i][:35]
        other_files = other_files + separated_files[i][35:]
        
    batch_one[i] = []
    batch_one_size[i] = 0
    total_number += len(sep_fil)
    for f in sep_fil:
        total += f[1]
        batch_one[i].append(f[0])
        batch_one_size[i] += f[1]

# %%
batch_one_size
# Out:
# {0: 1562.8,
#  1: 870.9999999999998,
#  2: 1084.1,
#  3: 780.0999999999999,
#  4: 1410.2,
#  5: 802.8000000000002,
#  6: 819.5000000000001,
#  7: 776.6999999999999,
#  8: 1269.3999999999999,
#  9: 563.3000000000001,
#  10: 628.6999999999999}

# %%
total
# Out:
# 10568.6

# %%
batch_one
# Out:
# {0: ['/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history1.xml-p30132p30303',
#   '/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2430920p2461498',
#   '/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2814172p2858587',
#   '/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2670685p2717436',
#   '/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2461499p2501546',
#   '/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2368392p2401909',
#   '/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2632005p2670684',
#   '/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2717437p2768997',
#   '/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2336425p2368391',
# ...

# %%
other_files
# Out:
# [('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history11.xml-p3424553p3473598',
#   36.5),
#  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history10.xml-p2556738p2593544',
#   38.9),
#  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history11.xml-p3473599p3514984',
#   40.7),
#  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history13.xml-p5040438p5096064',
#   48.0),
#  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history11.xml-p3232993p3271299',
#   49.1),
#  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history11.xml-p3706896p3746038',
#   58.9),
#  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history13.xml-p5137570p5189362',
#   78.1),
#  ('/datasets/enwiki-20181101-pages-meta-history/enwiki-20181101-pages-meta-history13.xml-p5096065p5137569',
#   350.9),
# ...
